# %%
import pandas as pd

# %%
x=pd.read_csv('nextcollectiondate.csv')

# %%
import pandas as pd
import numpy as np

d = {'col1': [0.0037448, -0.002455324, 0.003062666, 0.000768503, 0.002309015]}
df = pd.DataFrame(data=d)
dfT = df.T

np.matmul(dfT, df)
# Out:
# array([[3.53542131e-05]])

# %%
x.head()

# %%
x.tail()

# %%
x.describe()

# %%
y=x.iloc[:50,:]

# %%
tab  = pd.crosstab(index=x["collectionday"],columns="count")

# %%
tab

# %%
plt.plot(tab)
plt.show()

# %%
tab

# %%
tab.index

# %%
tab.count

# %%
tab

# %%
z=x['collectionday'].value_counts()

# %%
plt.plot(z)
plt.show()

# %%
plt.bar(tab.index,z)
plt.show()

# %%
tab  = pd.crosstab(index=y["address"],columns="count")

# %%
l=[]
chk=[r'Adair',r'Adela',r'Acacia',r'Cresvic',r'Victory',r'Red',r'Ainley',r'Ajax',r'Albert']
for i in chk:
    l.append(x.address.str.contains(i).sum())

# %%
value=[]

# %%
from itertools import permutations
import numpy as np

# %%
print(np.random.permutation(10)) # repeatation is not allowed
print(np.random.randint(1,10,10)) # number will be repeated
# Out:
# [9 4 3 1 8 2 0 7 6 5]
# [8 7 3 9 7 4 8 9 6 9]

# %%
l

# %%
plt.plot(chk,l)
plt.show()

# %%
plt.bar(chk,l)
plt.show()

# %%
x1=pd.date_range('20180727',periods=10)

# %%
x1

# %%
z1=x['nextwaste'].value_counts()

# %%
z1

# %%
tab  = pd.crosstab(index=x["nextwaste"],columns="count")

# %%
tab.index

# %%
axes = plt.axes()
axes.grid()
plt.xlabel('Dates of waste collected')
plt.ylabel('number of amount garbage collected/500')
plt.bar(tab.index,(z1/500))
plt.legend(['Blue'],loc=1)
plt.show()

# %%
import os
import io
print('hello world')

# %%
import datetime as dt

# %%
maxa = 'Sun 10 May 2015 13:54:36 -0700'
mini = 'Sun 10 May 2015 13:54:36 -0000'
maxa = 'Sat 02 May 2015 19:54:36 +0530'
mini ='Fri 01 May 2015 13:54:36 -0000'
from datetime import datetime as dt
fmt = '%a %d %b %Y %H:%M:%S %z'
for i in range(int(input())):
    
    print(int(abs((dt.strptime(maxa, fmt) - 
                   dt.strptime(mini, fmt)).total_seconds())))
# Out:
# 2
# 88200
# 88200

# %%
from datetime import datetime as dt
fmt = '%a %d %b %Y %H:%M:%S %z'
for i in range(int(input())):
    print(int(abs(dt.strptime(input() , fmt) - dt.strptime(input() , fmt)).total_seconds()))
# Out:
# 88200

# %%
# fibonacci()0 1 1 2 3 5
def fibonacci(n):
    if
    a = 0
    b = 1
    c = a + b
    l = []
    l.append(a)
    for i in range(n-1):
        l.append(c)
        c = a+b
        a = b
        b = c        
    return l
cube = lambda x : x**3
n = int(input())
print(list(map(cube,fibonacci(n))))
# Out:
# 1
# [0]

# %% [markdown]
# # Email Verification

# %%
s,t = input().split()
s ,t = int(s), int(t)
a,b = input().split()
a,b = int(a), int(b)
m,n = input().split()
m,n = int(m), int(n)
app = list(map(int,input().split()))
man = list(map(int,input().split()))
app = list(map(lambda x:x+a ,app)) 
man = list(map(lambda x:x+b ,man)) 
c = 0
for i in app:
    if i >= s:
        c+=1
print(c)
c = 0
for i in man:
    if i<= t:
        c+=1
print(c)
# Out:
# 7 11
# 5 15
# 3 2
# -2 2 1
# 5 -6

# %%
print(sum([1 for x in apple if (x + a) >= s and (x + a) <= t]))
print(sum([1 for x in orange if (x + b) >= s and (x + b) <= t]))
2 3
4 6
# Out:
# 2

# %%
obj = comple(2,1)
obj2 = comple(5,6)

# %%
print(obj - obj2)
# Out:
# 1.00-1.00i

# %%
(complex(2,1) * complex(5,6))
# Out:
# (4+17j)

# %% [markdown]
# # Debugging

# %%
import collections

# %%
l = ['a','e','i','o','u','y']
lj = ['programming','is','awesome']
sc = 0
for j in lj:
    a = dict(collections.Counter(j))
    print(a,end=" ")
    s = 0
    for i in a:
        if i in l:
            s += a[i]
    print('vowel ',s)
    if s%2==0:
        sc += 2
    else:
        sc += 1
print(sc)
# Out:
# {'p': 1, 'r': 2, 'o': 1, 'g': 2, 'a': 1, 'm': 2, 'i': 1, 'n': 1} vowel  3
# {'i': 1, 's': 1} vowel  1
# {'a': 1, 'w': 1, 'e': 2, 's': 1, 'o': 1, 'm': 1} vowel  4
# 4

# %%
matrix = []
for _ in range(7):
        matrix_item = input()
        matrix.append(matrix_item)
# Out:
# Tsi
# h%x
# i #
# sM
# $a
# #t%
# ir!

# %%
import re 
print(matrix)
s = re.sub(r'(\w)(\W)+(\w)',r'\1 \3',''.join([u for t in zip(*matrix) for u in t]))

print("{}".format(s))
s = ""
for i in zip(*matrix):
    for j in i:
        s+=j

print(re.sub(r'(\w)(\W)+(\w)',r'\1 \3',s))
# Out:
# ['Tsi', 'h%x', 'i #', 'sM ', '$a ', '#t%', 'ir!']
# This is Matrix#  %!
# This is Matrix#  %!

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(x, y, fxy, c='r', marker='o',s=10)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('F(x,y)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0

# %%
for i in range():

# %%
import time
from IPython import display
import pylab as pl

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('F(x,y)')
for i in (np.linspace(0.2,1.8,50)):
    x = np.linspace(-2+i,2-i,50)
    y = np.linspace(0.1+i,2-i,50)
    fxy = (x**2) / y
    ax.scatter3D(x, y, fxy, c='r', marker='o',s=10)
    display.clear_output(wait=True)
    display.display(pl.gcf())
    time.sleep(0.003)
# Out:
# <img src="data:image/png;base64,..." width="485.8181818181818">
